# %%
import tensorflow.compat.v1 as tf
import matplotlib.pyplot as plt
import numpy as np

tf.disable_eager_execution()

dataSet = np.loadtxt('서울특별시_부동산_실거래가_정보_2020년.csv', delimiter=',', dtype=np.float32)

x_data = dataSet[:, 0:3]
y_data = dataSet[:, [-2]]

x = tf.placeholder(tf.float32, shape=[None, 3])
y = tf.placeholder(tf.float32, shape=[None, 1])

W = tf.Variable(tf.random_normal([3, 1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

hypothesis = tf.matmul(x, W) + b

cost = tf.reduce_mean(tf.square(hypothesis - y))

optimizer = tf.train.GradientDescentOptimizer(learning_rate=1e-5)
train = optimizer.minimize(cost)

sess = tf.Session()
sess.run(tf.global_variables_initializer())

for step in range(10):
    cost_val, hy_val, _ = sess.run([cost, hypothesis, train], 
                                   feed_dict={x: x_data, y: y_data})
    print("Cost: ",cost_val, " Predict: ",hy_val)
# Out:
# Cost:  7.848434e+17  Predict:  [[13667.556]
#  [13628.685]
#  [13985.484]
#  ...
#  [13864.508]
#  [13868.54 ]
#  [13887.575]]
# Cost:  2.7220748e+24  Predict:  [[1.6274501e+12]
#  [1.6274869e+12]
#  [1.6620107e+12]
#  ...
#  [1.6490522e+12]
#  [1.6490514e+12]
#  [1.6490217e+12]]
# Cost:  1.8700131e+31  Predict:  [[-4.2639855e+15]
#  [-4.2640468e+15]
#  [-4.3545704e+15]
#  ...
#  [-4.3206040e+15]
#  [-4.3206023e+15]
#  [-4.3205538e+15]]
# Cost:  inf  Predict:  [[1.1175841e+19]
#  [1.1176001e+19]
#  [1.1413262e+19]
#  ...
#  [1.1324236e+19]
#  [1.1324233e+19]
#  [1.1324104e+19]]
# Cost:  inf  Predict:  [[-2.9292880e+22]
#  [-2.9293301e+22]
#  [-2.9915181e+22]
#  ...
#  [-2.9681838e+22]
#  [-2.9681829e+22]
#  [-2.9681494e+22]]
# Cost:  inf  Predict:  [[7.6780745e+25]
#  [7.6781847e+25]
#  [7.8411879e+25]
#  ...
#  [7.7800259e+25]
#  [7.7800241e+25]
#  [7.7799355e+25]]
# Cost:  inf  Predict:  [[-2.0124384e+29]
#  [-2.0124671e+29]
#  [-2.0551909e+29]
#  ...
#  [-2.0391602e+29]
# ...

# %%
# test = sess.run([hypothesis], feed_dict={'[시군코드, 대지권면적, 건물면적, 층 정보]를 입력하세요!'})

test = sess.run([hypothesis], feed_dict={[]})
